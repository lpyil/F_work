# %% [markdown]
# https://pandas.pydata.org/docs/index.html

# %%
import pandas as pd

# %% [markdown]
# data from file

# %%
df = pd.read_csv('pokemon_data.csv')  # reading data file
df = pd.read_excel('pokemon_data.xlsx')  # excel
df = pd.read_csv('pokemon_data.txt', delimiter='\t')  # seperated tab
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(df.head(3))  # read first 3
print(df.tail(3))  # last 3
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# Reading Data in Pandas

# %%
df.columns  # Headers
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name'][0:5]  # specific
df.Name[0:5]  # or
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
print(df[['Name', 'Type 1', 'HP']])
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
print(df.iloc[2], "\n")  # row

# for row in df.iterrows(): # all
#    print(row)
# Out:
# #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object

# %%
df.iloc[2, 1]  # specific
df.iloc[2][1]
# Out:
# 'Venusaur'

# %%
df.loc[df['Legendary'] == True]  # Print True ones
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Type 1', ascending=False)
# Out:
#        #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 371  339  Barboach  Water  Ground  50      48       43       46       41
# 97    90  Shellder  Water     NaN  30      65      100       45       25
# 240  222   Corsola  Water    Rock  55      55       85       65       85
# 403  368  Gorebyss  Water     NaN  55      84      105      114       75
# 93    86      Seel  Water     NaN  65      45       55       45       70
# ..   ...       ...    ...     ...  ..     ...      ...      ...      ...
# 54    49  Venomoth    Bug  Poison  70      65       60       90       75
# 208  193     Yanma    Bug  Flying  65      65       45       75       45
# 182  168   Ariados    Bug  Poison  70      90       70       60       60
# 734  666  Vivillon    Bug  Flying  80      52       50       90       50
# 179  165    Ledyba    Bug  Flying  40      20       30       40       80
#
#      Speed  Generation  Legendary
# 371     60           3      False
# ...

# %%
df.sort_values(['Type 1', 'HP'])  # ascending= [1,0] type + -
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# Making changes to the data

# %% [markdown]
#     *Add column

# %%
# add column

df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + \
    df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    318
# 1           1      False    405
# 2           1      False    525

# %% [markdown]
#     *Delete Column

# %%
df = df.drop(columns=['Total'])  # remove column
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %% [markdown]
#     *Adding // 2

# %%
df['Total'] = df.iloc[:, 4: 10].sum(axis=1)  # axis 1 --> column
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    318
# 1           1      False    405
# 2           1      False    525

# %%
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %% [markdown]
#     Save as diffrent file

# %%
df.to_csv('modified.csv', index=False)
df.to_excel('modified.xlsx', index=False)
df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# Filtering

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Fighting') & (
    df['Speed'] > 65)]  # using and or make error
new_df
# Out:
#        #      Name Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 310  286   Breloom  Grass  Fighting    460  60     130       80       60
# 701  640  Virizion  Grass  Fighting    580  91      90       72       90
#
#      Sp. Def  Speed  Generation  Legendary
# 310       60     70           3      False
# 701      129    108           5       True

# %%
new_df = new_df.reset_index(drop=True)  # inplace ???
new_df
# Out:
#      #      Name Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  286   Breloom  Grass  Fighting    460  60     130       80       60
# 1  640  Virizion  Grass  Fighting    580  91      90       72       90
#
#    Sp. Def  Speed  Generation  Legendary
# 0       60     70           3      False
# 1      129    108           5       True

# %%
df.loc[df['Name'].str.contains('Mega')]  # find include mega // ~ not
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %%
import re  # regular exp

df.loc[df['Type 1'].str.contains('Fire|Water', regex=True)]
# for ignore captl --> , flags=re.I
# Out:
#        #                       Name Type 1  Type 2  Total  HP  Attack  \
# 4      4                 Charmander   Fire     NaN    309  39      52
# 5      5                 Charmeleon   Fire     NaN    405  58      64
# 6      6                  Charizard   Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X   Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y   Fire  Flying    634  78     104
# ..   ...                        ...    ...     ...    ...  ..     ...
# 735  667                     Litleo   Fire  Normal    369  62      50
# 736  668                     Pyroar   Fire  Normal    507  86      68
# 762  692                  Clauncher  Water     NaN    330  50      53
# 763  693                  Clawitzer  Water     NaN    500  71      73
# 799  721                  Volcanion   Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4         43       60       50     65           1      False
# ...

# %%
df.loc[df['Name'].str.contains('Pikachu', flags=re.I)]  # Find pikachu
# Find contains pi anywhere
df.loc[df['Name'].str.contains('pi[a-z]*', flags=re.I)]
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I)]  # Start at pi
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# ...

# %% [markdown]
# Conditonal Changes

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'  # like if in one line
df
df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'
df

# df.loc[df['Total'] > 500, ['Generation', 'Legandary']] = ['x1', 'x2']
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# Aggregate Statistics (Groupby)

# %%
df.groupby(['Type 1']).mean().sort_values('Attack')
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# ...

# %%
df['count'] = 1
df.groupby(['Type 1']).count()['count'].sort_values(ascending=False)
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# Work large amounts of data

# %%
# df = pd.read_csv('modified.csv') # Load all data
for df in pd.read_csv('modified.csv', chunksize=50):  # load each 50
    print('CHUNK DF')
    # print(df) all of them
# Out:
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF
# CHUNK DF

# %%
new_df = pd.DataFrame(columns=df.columns)  # make empty with same columns
new_df
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %% [markdown]
# Cursed --> GO back again:

# %%
df = pd.read_csv('modified.csv', chunksize=10)
df

# %%
for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    new_df = pd.concat([new_df, results])

new_df.to_csv('test_2.txt', index=False, sep='\t')

# %%
new_df
# Out:
#          # Name Type 1 Type 2 Total HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire     1    1    NaN      0     1  1      1       1       1       1     1
# Grass    4    4    NaN      4     4  4      4       4       4       4     4
# Fire     4    4    NaN      3     4  4      4       4       4       4     4
# Water    1    1    NaN      0     1  1      1       1       1       1     1
# Bug      2    2    NaN      0     2  2      2       2       2       2     2
# ...     ..  ...    ...    ...   ... ..    ...     ...     ...     ...   ...
# Fairy    1    1    NaN      0     1  1      1       1       1       1     1
# Flying   2    2    NaN      2     2  2      2       2       2       2     2
# Fire     1    1    NaN      1     1  1      1       1       1       1     1
# Psychic  2    2    NaN      2     2  2      2       2       2       2     2
# Rock     2    2    NaN      2     2  2      2       2       2       2     2
#
#         Generation Legendary
# ...
